# %% [markdown]
# <a href="https://colab.research.google.com/github/nugi-ML/Dasar-Python/blob/main/08_Jenis_jenis_Operator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Operator Aritmetika

# %%
x = 11
y = 5

print(x + y)
print(x - y)
print(x * y)
print(x // y)
print(x / y)
print(x % y)
print(x ** y)
# Out:
# 16
# 6
# 55
# 2
# 2.2
# 1
# 161051

# %% [markdown]
# ## Operator Relasional

# %%
x = 5
y = 10

print(x == y)
print(x != y)
print(x > y)
print(x < y)
print(x >= y)
print(x <= y)
# Out:
# False
# True
# False
# True
# False
# True

# %%
x = "Dicoding"
y = "Indonesia"

print(x == y)
print(x != y)
print(x > y)
print(x < y)
print(x >= y)
print(x <= y)
# Out:
# False
# True
# False
# True
# False
# True

# %% [markdown]
# ## Operator Logika

# %% [markdown]
# ### Operator End

# %%
print(True and True)
print(True and False)
print(False and True)
print(False and False)
# Out:
# True
# False
# False
# False

# %% [markdown]
# ### Operator OR

# %%
print(True or True)
print(True or False)
print(False or True)
print(False or False)
# Out:
# True
# True
# True
# False

# %% [markdown]
# ### Operator NOT

# %%
print(not True)
print(not False)
# Out:
# False
# True

# %% [markdown]
# ## Operator Assignment

# %%
# +=
x = 11
x += 5
print(x)

# -=
x = 11
x -= 5
print(x)

# *=
x = 11
x *= 5
print(x)

# /=
x = 11
x /= 5
print(x)

#%=
x = 11
x%= 5
print(x)
# Out:
# 16
# 6
# 55
# 2.2
# 1

# %%
x = 11
x += 5
print(x)


x = 11
x = x + 5
print(x)
# Out:
# 16
# 16
