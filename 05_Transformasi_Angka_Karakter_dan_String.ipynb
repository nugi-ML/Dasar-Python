# %% [markdown]
# <a href="https://colab.research.google.com/github/nugi-ML/Dasar-Python/blob/main/05_Transformasi_Angka_Karakter_dan_String.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mengubah Huruf Besar/Kecil

# %% [markdown]
# ### `upper()`

# %%
kata = 'indonesia'
kata = kata.upper()
print(kata)
# Out:
# INDONESIA

# %% [markdown]
# ### `lower()`

# %%
kata = 'INDONESIA'
kata = kata.lower()
print(kata)
# Out:
# indonesia

# %% [markdown]
# # Awalan dan Akhiran

# %% [markdown]
# ### `rstrip()`

# %%
print('Indonesia        '.rstrip())
# Out:
# Indonesia

# %% [markdown]
# ### `lstrip()`

# %%
print('       Indonesia'.lstrip())
# Out:
# Indonesia

# %% [markdown]
# ### `strip()`

# %%
print('   Indonesia   '.strip())
# Out:
# Indonesia

# %%
kata = 'CodeCodeIndonesiaCodeCode'
print(kata.strip('Code'))
# Out:
# Indonesia

# %% [markdown]
# ### `startswith()`

# %%
print('Dicoding Indonesia'.startswith('Dicoding'))
# Out:
# True

# %% [markdown]
# ### `endswith()`

# %%
print('Dicoding Indonesia'.endswith('Dicoding'))
# Out:
# False

# %% [markdown]
# # Memisah dan Menggabung String

# %% [markdown]
# ### `join()`

# %%
print(' '.join(['Dicoding', 'Indonesia', '!']))
# Out:
# Dicoding Indonesia !

# %%
print('123'.join(['Dicoding', 'Indonesia', '!']))
# Out:
# Dicoding123Indonesia123!

# %% [markdown]
# ### `split()`

# %%
print('Dicoding Indonesia !'.split())
# Out:
# ['Dicoding', 'Indonesia', '!']

# %%
print('''
Aku adalah Manusia,
Aku menyukai Wanita
Aku tinggal di bumi
'''.split('\n'))
# Out:
# ['', 'Aku adalah Manusia,', 'Aku menyukai Wanita', 'Aku tinggal di bumi', '']

# %% [markdown]
# # Mengganti Elemen String

# %% [markdown]
# ### `replace()`

# %%
string = 'Ayo belajar Bahasa Python'
print(string.replace('Bahasa', 'Pemrograman'))
# Out:
# Ayo belajar Pemrograman Python

# %% [markdown]
# # Pengecekan String

# %% [markdown]
# ### `isupper()`

# %%
kata = 'DICODING'
print(kata.isupper())
# Out:
# True

# %% [markdown]
# ### `islower()`

# %%
kata = 'dicoding'
print(kata.islower())
# Out:
# True

# %% [markdown]
# ### `isalpha()`

# %%
kata = 'indonesia'
print(kata.isalpha())
# Out:
# True

# %%
kata = '1ndonesia'
print(kata.isalpha())
# Out:
# False

# %% [markdown]
# ### `isalnum()`

# %%
kata = '1ndonesia'
print(kata.isalnum())
# Out:
# True

# %% [markdown]
# ### `isdecimal()`

# %%
print('123'.isdecimal())
# Out:
# True

# %% [markdown]
# ### `isspace()`

# %%
print('         '.isspace())
# Out:
# True

# %% [markdown]
# ### `istitle()`

# %%
print('Tanah Air'.istitle())
# Out:
# True

# %% [markdown]
# # Formatting pada String

# %% [markdown]
# ### `zfill()`

# %%
teks = 'Code'
tambah_number = teks.zfill(5)
print(tambah_number)
# Out:
# 0Code

# %% [markdown]
# ### `rjust()`

# %%
print('Indonesia'.rjust(20))
# Out:
#            Indonesia

# %%
print('Indonesia'.rjust(20, '!'))
# Out:
# !!!!!!!!!!!Indonesia

# %% [markdown]
# ### `ljust()`

# %%
print('Indonesia'.ljust(20, '*'))
# Out:
# Indonesia***********

# %% [markdown]
# ### `center()`

# %%
print('Indonesia'.center(11, '-'))
# Out:
# -Indonesia-
