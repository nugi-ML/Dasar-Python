# %% [markdown]
# <a href="https://colab.research.google.com/github/nugi-ML/Dasar-Python/blob/main/02_InputOutput_dan_Komentar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Input

# %% [markdown]
# Untuk memungkinkan pengguna memberikan masukan, Anda dapat menggunakan perintah `input()`. Berikut implementasinya menggunakan Python.

# %%
name = input('Masukan nama Anda: ')
# Out:
# Masukan nama Anda: asd

# %% [markdown]
# # Output

# %% [markdown]
# Fungsi print() adalah perintah untuk menampilkan output ke layar komputer Anda.

# %%
name = input('Masukan nama Anda: ')
print(name)
# Out:
# Masukan nama Anda: nugi
# nugi

# %% [markdown]
# # Comment

# %% [markdown]
# Komentar merupakan barisan teks yang akan diabaikan oleh Python ketika program tersebut dijalankan. Anda dapat menulis satu atau beberapa baris teks sebagai komentar dalam kode program.

# %% [markdown]
# ## Inline Comment

# %% [markdown]
# Inline comment pada Python merupakan komentar yang biasanya diletakkan pada baris yang sama dengan kode atau satu baris sebelum kode.

# %%
# Variabel ini menyimpan nama 'Perseus Evans'
name = 'Perseus Evans'

# %% [markdown]
# ## Block Comment

# %% [markdown]
# Berbeda dengan inline comment yang hanya satu baris, block comment merupakan satu blok kode dengan tujuan menjelaskan kode kompleks atau membuat dokumentasi dari sebuah fungsi atau modul.

# %%
"""
Ini adalah Block Comment,
Teks ini akan diabaikan oleh Python.
"""
print("Hello World!")
# Out:
# Hello World!

# %%
'''
Ini adalah Block Comment,
Teks ini akan diabaikan oleh Python.
'''
print("Hello World!")
# Out:
# Hello World!
